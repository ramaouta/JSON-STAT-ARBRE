# %%
import pandas 
zone = ['PARIS 18E ARRDT', 'none', 'PARIS 17E ARRDT', 'none', 'PARIS 13E ARRDT', 'PARIS 16E ARRDT', 'none', 'PARIS 20E ARRDT', 'PARIS 14E ARRDT', 'none', 'PARIS 11E ARRDT', 'none', 'none', 'PARIS 12E ARRDT', 'none', 'none', 'PARIS 5E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 15E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 10E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 19E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 9E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 4E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 7E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 8E ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'PARIS 1ER ARRDT', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none', 'none']
arr_df = pandas.read_csv("arrondissements.csv", sep = ';', header = 0)
#arr_df = arr_df.drop("Numéro d’arrondissement INSEE", axis = 1)
#arr_df = arr_df.drop("Nom officiel de l’arrondissement", axis = 1)
#arr_df = arr_df.drop("N_SQ_CO", axis = 1)



a = arr_frame.loc[(arr_frame ["Numéro d’arrondissement"] == 'PARIS 18E ARRDT' ) & (arr_frame["Geometry X Y"])]
a
# Out:
# Empty DataFrame
# Columns: [Identifiant séquentiel de l’arrondissement, Numéro d’arrondissement, Numéro d’arrondissement INSEE, Nom de l’arrondissement, Nom officiel de l’arrondissement, N_SQ_CO, Surface, Périmètre, Geometry X Y, Geometry]
# Index: []

# %%
localisation= {
    'PARIS 20E ARRDT': [48.86346057889563,2.401188129284682],
    'PARIS 19E ARRDT':[48.8870756373184,2.384820702561691]
} 
a = 'PARIS 20E ARRDT'
if a in localisation : 
    print(localisation[a][0])
# Out:
# 48.86346057889563

# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

data = pandas.read_csv("new_arbres.csv")
data_saisi=["BOIS DE VINCENNES","Platane","Quantité"]
data.drop(data.index[data['HAUTEUR (m)']>50], inplace=True)
data.drop(data.index[data['HAUTEUR (m)']<2], inplace=True)

    ##################     one,one,hauteur      #########################
data_demo_one_one=data.loc[(data['ARRONDISSEMENT']==data_saisi[0]) & (data["LIBELLE FRANCAIS"]==data_saisi[1]), :]
g = data_demo_one_one.groupby('ARRONDISSEMENT')
data_one_one = g[['HAUTEUR (m)']].agg([pandas.Series.mean, pandas.Series.max, pandas.Series.min])
data_one_one.columns=['MEAN', 'MAX', 'MIN']
data_one_one.insert(0,"TYPE",data_saisi[1])

     #####################    one,tous,hauteur   ###############################
data_demo_one_tous=data.loc[(data['ARRONDISSEMENT']==data_saisi[0]) & (data["LIBELLE FRANCAIS"]!=data_saisi[1]), :]
g = data_demo_one_tous.groupby('ARRONDISSEMENT')
data_one_tous = g[['HAUTEUR (m)']].agg([pandas.Series.mean, pandas.Series.max, pandas.Series.min])
data_one_tous.columns=['MEAN', 'MAX', 'MIN']
data_one_tous.insert(0,"TYPE","AUTRE")

    #####################    tous,tous,hauteur   ###############################
data_demo_tous_tous=data.loc[(data['ARRONDISSEMENT']!=data_saisi[0]) & (data["LIBELLE FRANCAIS"]==data_saisi[1]), :]
g = data_demo_tous_tous.groupby('ARRONDISSEMENT')
data_tous_tous = g[['HAUTEUR (m)']].agg([pandas.Series.mean, pandas.Series.max, pandas.Series.min])
data_tous_tous.columns=['MEAN', 'MAX', 'MIN']
data_tous_tous.sort_values(by=["MAX"],ascending=False)
data_tous_tous.sort_values(by=["MIN"],ascending=False)
data_tous_tous.insert(0,"TYPE",f"{data_saisi[1]} dans les autres arrondissements")
temp_moyenne_valeur=[int(elem) for elem in data_tous_tous["MEAN"]]
moyenne_autre_arrondissement=[int(int(sum(temp_moyenne_valeur))/len(temp_moyenne_valeur))]

    #####################    listes   ###############################
element=[]
element.append(data_one_one["TYPE"][0])
element.append(data_one_tous["TYPE"][0])
element.append(data_tous_tous["TYPE"][0])

maximums=[]
maximums.extend(data_one_one["MAX"])
maximums.extend(data_one_tous["MAX"])
maximums.append(data_tous_tous["MAX"][0])

minimums=[]
minimums.extend(data_one_one["MIN"])
minimums.extend(data_one_tous["MIN"])
minimums.append(data_tous_tous["MIN"][0])

moyennes=[]
moyennes.extend(int(elem) for elem in data_one_one["MEAN"])
moyennes.extend(int(elem) for elem in data_one_tous["MEAN"])
moyennes.extend(moyenne_autre_arrondissement)

    ####################### GRAPHE   #################################"
f, ax = plt.subplots(figsize=(5,5))
font = {'family' : 'Arial','size' : 12}
plt.rc('font', **font)
plt.title(f'la compariason entre les moyennes ,les maximums et les minimums hauteurs de \"{data_saisi[1]}\" avec tous les types presents \n dans \"{data_saisi[0]}\" et tous les types dans les autres arrondissements \n\n', fontsize=13)

sns.set_color_codes("pastel")
sns.barplot(x=element, y=maximums,
        	label='Maximum', color="g")

sns.set_color_codes("muted")
sns.barplot(x=element, y=moyennes,
        	label="Moyenne", color="y")

sns.set_color_codes("bright")
sns.barplot(x=element, y=minimums,
        	label='Minimum', color="r")



ax.legend(ncol=3, loc="upper right", frameon=True)
ax.set(ylim=(0,50),xlim=(-0.5, 3), ylabel="Hauteur",
   	xlabel=f"\n\n\n - premiere barre : les éléments chosis \n deuxième barre : tous les types presents dans l'arrondissement choisi \n troisième barre : le type choisi dans les autres arrondissements ")
# plt.xticks(rotation=20)
sns.despine(right=True, top=True)

# %%
new_df = pandas.read_csv("new_arbres.csv") 
dataQ1 = new_df
        #suppression de l arbre'hauteur superieur à 50 et inferieur à 2
dataQ1.drop(dataQ1.index[dataQ1['HAUTEUR (m)']>50], inplace=True)
dataQ1.drop(dataQ1.index[dataQ1['HAUTEUR (m)']<2], inplace=True)

dataQ1 = dataQ1.loc[ (dataQ1['ARRONDISSEMENT']== "PARIS 16E ARRDT" )&(dataQ1['LIBELLE FRANCAIS']== "Platane" ),  :]
# Out:
#         Unnamed: 0  IDBASE   ARRONDISSEMENT LIBELLE FRANCAIS  \
# 53              53  254281  PARIS 16E ARRDT          Platane
# 234            234  248170  PARIS 16E ARRDT          Platane
# 287            287  220891  PARIS 16E ARRDT          Platane
# 355            355  221686  PARIS 16E ARRDT          Platane
# 400            400  263700  PARIS 16E ARRDT          Platane
# ...            ...     ...              ...              ...
# 205722      205722  252190  PARIS 16E ARRDT          Platane
# 205799      205799  262622  PARIS 16E ARRDT          Platane
# 205830      205830  264407  PARIS 16E ARRDT          Platane
# 205831      205831  264752  PARIS 16E ARRDT          Platane
# 205839      205839  252660  PARIS 16E ARRDT          Platane
#
#         CIRCONFERENCE (cm)  HAUTEUR (m) STADE DE DEVELOPPEMENT   LATITUDE  \
# 53                      96            9    Jeune (arbre)Adulte  48.846823
# 234                     85           10    Jeune (arbre)Adulte  48.854055
# ...

# %%
g = dataQ1.groupby('ARRONDISSEMENT')
data_one_one = g[['HAUTEUR (m)']].agg([pandas.Series.mean, pandas.Series.max, pandas.Series.min])
data_one_one.columns=['MEAN', 'MAX', 'MIN']

data_one_one.insert(0,"TYPE",data_saisi[1])
data_demo_one_tous=data.loc[(data['ARRONDISSEMENT']==data_saisi[0]) & (data["LIBELLE FRANCAIS"]!=data_saisi[1]), :]
g = data_demo_one_tous.groupby('ARRONDISSEMENT')

data_one_tous = g[['HAUTEUR (m)']].agg([pandas.Series.mean, pandas.Series.max, pandas.Series.min])
data_one_tous.columns=['MEAN', 'MAX', 'MIN']
data_one_tous.insert(0,"TYPE","AUTRE")
data_one_tous
#p=dataQ1.loc[dataQ1['HAUTEUR (m)'] == 35 , :]
#dataQ1 = dataQ1.loc[dataQ1['LIBELLE FRANCAIS']== data[1], :]
# Out:
#                     TYPE       MEAN  MAX  MIN
# ARRONDISSEMENT
# BOIS DE VINCENNES  AUTRE  11.370352   33    2

# %%
new_df = pandas.read_csv("new_arbres.csv") 
dataQ1 = new_df
        #suppression de l arbre'hauteur superieur à 50 et inferieur à 2
dataQ1.drop(dataQ1.index[dataQ1['HAUTEUR (m)']>50], inplace=True)
dataQ1.drop(dataQ1.index[dataQ1['HAUTEUR (m)']<2], inplace=True)

dataQ1 = dataQ1.loc[ (dataQ1['ARRONDISSEMENT']== "PARIS 16E ARRDT" )&(dataQ1['LIBELLE FRANCAIS']== "Platane" ),  :]
# Out:
#         Unnamed: 0  IDBASE   ARRONDISSEMENT LIBELLE FRANCAIS  \
# 53              53  254281  PARIS 16E ARRDT          Platane
# 234            234  248170  PARIS 16E ARRDT          Platane
# 287            287  220891  PARIS 16E ARRDT          Platane
# 355            355  221686  PARIS 16E ARRDT          Platane
# 400            400  263700  PARIS 16E ARRDT          Platane
# ...            ...     ...              ...              ...
# 205722      205722  252190  PARIS 16E ARRDT          Platane
# 205799      205799  262622  PARIS 16E ARRDT          Platane
# 205830      205830  264407  PARIS 16E ARRDT          Platane
# 205831      205831  264752  PARIS 16E ARRDT          Platane
# 205839      205839  252660  PARIS 16E ARRDT          Platane
#
#         CIRCONFERENCE (cm)  HAUTEUR (m) STADE DE DEVELOPPEMENT   LATITUDE  \
# 53                      96            9    Jeune (arbre)Adulte  48.846823
# 234                     85           10    Jeune (arbre)Adulte  48.854055
# ...

# %%
liste_hauteur =[]
marqueurs ={}
for i , row in dataQ1.iterrows(): 
            coordonner = []
            coordonner.append(row['LATITUDE']) ; coordonner.append(row['LONGITUDE'])
            #liste_hauteur.append(row['HAUTEUR (m)'])
           
            #marqueurs[str(row['HAUTEUR (m)'])+"(m)_"+str(i)] = coordonner
            #print(str(row['HAUTEUR (m)'])+"(m)_"+str(i))
            #  for el in liste_hauteur :
            #  map_widget.set_marker(localisation[el][0], localisation[el][1] , text= el)
            #  el 
            #  row['LATITUDE'] 
            #  row['LONGITUDE'] 

            #i = str(i)[1:-1]
a = "10(m)_234"
k = ""
for j in a : 
    if j != "_" : 
        k = str(k)+str(j)
    else : 
        break 
print(k)            #i = i.replace(_,"")
# Out:
# 10(m)
